# %% [markdown]
# # YOLOR Custom Training for Speed Breaker Detection
#
# This notebook demonstrates custom training of YOLOR model.

# %%
import torch
import yaml
from pathlib import Path

# %% [markdown]
# ## Setup Training Configuration

# %%
# Training hyperparameters
cfg = {
    'epochs': 100,
    'batch_size': 16,
    'img_size': 640,
    'data': 'data.yaml'
}
